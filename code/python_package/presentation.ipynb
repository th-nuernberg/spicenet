# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_plt_vals = np.linspace(-1, 1, 500)
y_plt_vals = x_plt_vals ** 3

plt.plot(x_plt_vals, y_plt_vals)

# %%
import spice_net as spn
import pandas as pd

df = pd.read_csv('data/test_data.csv')

som = spn.SpiceNetSom(50,-1, 1, spn.declining_linear_lrf_from_interval(0.8, 0.2, 3000), spn.declining_linear_lrf_from_interval(0.9, 0.9, 3000))
som.fit(df['init'],1)
spn.plot_som_comparison_to_data(som, df['init'].tolist())
